# %%
# %%capture
# !pip install llama-index==0.10.37 html2text

# %%
import os

from getpass import getpass
import nest_asyncio

from dotenv import load_dotenv

nest_asyncio.apply()

load_dotenv()
# Out:
# True

# %% [markdown]
# # 📂 **Loading Data**
#
# Preparing your data for an LLM involves an ingestion pipeline similar to ML data cleaning or traditional ETL processes.
#
# ### **Ingestion Pipeline Stages**
#   - 📥 Load the data
#   - 🔧 Transform the data
#   - 🗃️ Index and store the data
#
#
# Let's start by downloading some example files

# %%
import requests
from pathlib import Path

# Base URL for Project Gutenberg texts
base_url = "https://www.gutenberg.org/cache/epub/{book_id}/pg{book_id}.txt"

# Directory to save the downloaded files
directory = Path("../data")

# Create the directory if it doesn't exist
directory.mkdir(parents=True, exist_ok=True)

# Generate a list of book IDs to download
book_ids = range(1, 11)  # This will create a range from 1 to 10

# Generate URLs for each book ID
urls = [base_url.format(book_id=book_id) for book_id in book_ids]

# Download each file and save it in the specified directory
for url in urls:
    response = requests.get(url)
    if response.status_code == 200:
        # Extract the filename from the URL using the book ID and create a file name
        book_id = url.split('/')[-2]  # Extracts the book ID from the URL
        filename = f"pg{book_id}.txt"
        file_path = directory / filename
        # Save the file to the specified directory
        file_path.write_text(response.text)
        print(f"Downloaded {filename} to {file_path}")
    else:
        print(f"Failed to download {url}. HTTP status code: {response.status_code}")
# Out:
# Downloaded pg1.txt to ../data/pg1.txt
# Downloaded pg2.txt to ../data/pg2.txt
# Downloaded pg3.txt to ../data/pg3.txt
# Downloaded pg4.txt to ../data/pg4.txt
# Downloaded pg5.txt to ../data/pg5.txt
# Downloaded pg6.txt to ../data/pg6.txt
# Downloaded pg7.txt to ../data/pg7.txt
# Downloaded pg8.txt to ../data/pg8.txt
# Downloaded pg9.txt to ../data/pg9.txt
# Downloaded pg10.txt to ../data/pg10.txt

# %%
# !pip install --upgrade llama-index-readers-file
# Out:
# Requirement already satisfied: llama-index-readers-file in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (0.4.5)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-readers-file) (4.12.3)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-readers-file) (0.12.17)
# Requirement already satisfied: pandas in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-readers-file) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-readers-file) (5.3.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-readers-file) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file) (2.5)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.11.12)
# Requirement already satisfied: dataclasses-json in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2025.2.0)
# Requirement already satisfied: httpx in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.9.1)
# Requirement already satisfied: numpy in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from pandas->llama-index-readers-file) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from pandas->llama-index-readers-file) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from pandas->llama-index-readers-file) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.18.3)
# Requirement already satisfied: click in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.27.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.26.1)
# Requirement already satisfied: anyio in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.2)
# Requirement already satisfied: sniffio in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (24.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/lil_llama_index/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.0)

# %%
from llama_index.core import SimpleDirectoryReader
import os

# Check if the directory exists and list its contents
data_dir = "/workspaces/hands-on-ai-rag-using-llamaindex-3830207/data"
if os.path.exists(data_dir):
    print(f"Directory exists: {data_dir}")
    print("Contents of the directory:", os.listdir(data_dir))
else:
    print(f"Directory does not exist: {data_dir}")

# Attempt to load the documents
try:
    documents = SimpleDirectoryReader(data_dir).load_data()
    print(f"Number of documents loaded: {len(documents)}")
except Exception as e:
    print(f"Error loading documents: {e}")
# Out:
# Directory exists: /workspaces/hands-on-ai-rag-using-llamaindex-3830207/data
# Contents of the directory: ['skin_in_the_game.pdf', 'almanack_of_naval_ravikant.pdf', 'pg5.txt', 'striking-thoughts.pdf', 'taoofseneca_vol2.pdf', 'pg2.txt', 'pg10.txt', 'pg9.txt', 'pg1.txt', 'taoofseneca_vol1-1.pdf', 'pg8.txt', 'pg4.txt', 'pg3.txt', 'pg7.txt', 'anthology_of_balaji.pdf', 'taoofseneca_vol3.pdf', 'hackers_and_painters.pdf', 'pg6.txt']
# Error loading documents: `llama-index-readers-file` package not found

# %% [markdown]
# # 📥 Load the data
#
# To use data with an LLM, first load it using data connectors, known as `Readers` in LlamaIndex, which format data into `Document` objects containing data and metadata.
#
# 📚 **SimpleDirectoryReader**:
#   - The most straightforward loader is `SimpleDirectoryReader``.
#   - Built into LlamaIndex, it reads various formats (Markdown, PDFs, Word documents, PowerPoint decks, images, audio, video) from every file in a directory, creating documents.

# %%
# from llama_index.core import SimpleDirectoryReader
# documents = SimpleDirectoryReader("/workspaces/hands-on-ai-rag-using-llamaindex-3830207/data").load_data()
from llama_index.core import SimpleDirectoryReader
import os
documents=[]
# Check if the directory exists and list its contents
data_dir = "/workspaces/hands-on-ai-rag-using-llamaindex-3830207/data"
if os.path.exists(data_dir):
    print(f"Directory exists: {data_dir}")
    print("Contents of the directory:", os.listdir(data_dir))
else:
    print(f"Directory does not exist: {data_dir}")

# Attempt to load the documents
try:
    documents = SimpleDirectoryReader(data_dir).load_data()
    print(f"Number of documents loaded: {len(documents)}")
    print(documents)
except Exception as e:
    print(f"Error loading documents: {e}")

# documents = SimpleDirectoryReader(data_dir).load_data()
# print(documents)
# Out:
# Directory exists: /workspaces/hands-on-ai-rag-using-llamaindex-3830207/data
# Contents of the directory: ['skin_in_the_game.pdf', 'almanack_of_naval_ravikant.pdf', 'pg5.txt', 'striking-thoughts.pdf', 'taoofseneca_vol2.pdf', 'pg2.txt', 'pg10.txt', 'pg9.txt', 'pg1.txt', 'taoofseneca_vol1-1.pdf', 'pg8.txt', 'pg4.txt', 'pg3.txt', 'pg7.txt', 'anthology_of_balaji.pdf', 'taoofseneca_vol3.pdf', 'hackers_and_painters.pdf', 'pg6.txt']
# Error loading documents: `llama-index-readers-file` package not found

# %%
import os
data_dir = "/workspaces/hands-on-ai-rag-using-llamaindex-3830207/data"
documents  = []
if os.path.exists(data_dir):
    print(f"Directory exists: {data_dir}")
    print("Contents of the directory:", os.listdir(data_dir))
    documents = os.listdir(data_dir)
else:
    print(f"Directory does not exist: {data_dir}")

print(f"documents: {documents}")
len(documents)
# Out:
# Directory exists: /workspaces/hands-on-ai-rag-using-llamaindex-3830207/data
# Contents of the directory: ['skin_in_the_game.pdf', 'almanack_of_naval_ravikant.pdf', 'pg5.txt', 'striking-thoughts.pdf', 'taoofseneca_vol2.pdf', 'pg2.txt', 'pg10.txt', 'pg9.txt', 'pg1.txt', 'taoofseneca_vol1-1.pdf', 'pg8.txt', 'pg4.txt', 'pg3.txt', 'pg7.txt', 'anthology_of_balaji.pdf', 'taoofseneca_vol3.pdf', 'hackers_and_painters.pdf', 'pg6.txt']
# documents: ['skin_in_the_game.pdf', 'almanack_of_naval_ravikant.pdf', 'pg5.txt', 'striking-thoughts.pdf', 'taoofseneca_vol2.pdf', 'pg2.txt', 'pg10.txt', 'pg9.txt', 'pg1.txt', 'taoofseneca_vol1-1.pdf', 'pg8.txt', 'pg4.txt', 'pg3.txt', 'pg7.txt', 'anthology_of_balaji.pdf', 'taoofseneca_vol3.pdf', 'hackers_and_painters.pdf', 'pg6.txt']
# 18

# %%
type(documents[0])
# Out:
# str

# %%
print(documents[3])   # string document, while SimpleDirectoryReader(data_dir).load_data()-> List[Diuct]

d = Document(pdf=documents[3])  
d.__dict__

#documents[3].__dict__
# Out:
# striking-thoughts.pdf
# {'id_': '8d89b958-52f1-4278-b993-b7e6cb2e114d',
#  'embedding': None,
#  'metadata': {},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {},
#  'text': '',
#  'mimetype': 'text/plain',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n'}

# %% [markdown]
# ##### Manually Create Document Objects

# %%
from llama_index.core import Document

manual_document = Document(text="This is an example of a manual document")

# %%
manual_document.__dict__
# Out:
# {'id_': '5a661586-4c37-4190-91fc-ea816abf0698',
#  'embedding': None,
#  'metadata': {},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {},
#  'text': 'This is an example of a manual document',
#  'mimetype': 'text/plain',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n'}

# %% [markdown]
# ##### Adding metadata
#
# You can add metadata in the document constructor:

# %%
manual_document_with_metadata = Document(
    text="This is an example of a manual document",
    metadata={"filename": "made-up-file-name", "category": "imaginary-category"}
)

# %%
manual_document_with_metadata.__dict__

# %% [markdown]
# Or after the document is created

# %%
manual_document.metadata={"filename": "made-up-file-name", "category": "imaginary-category"}

# %%
manual_document.__dict__
# Out:
# {'id_': '5a661586-4c37-4190-91fc-ea816abf0698',
#  'embedding': None,
#  'metadata': {'filename': 'made-up-file-name',
#   'category': 'imaginary-category'},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {},
#  'text': 'This is an example of a manual document',
#  'mimetype': 'text/plain',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n'}

# %% [markdown]
# # 🔧 Transform the data
#
# After loading, we must process and transform data for retrieval. We need to transform the list of `Document` objects into `Node` objects
#
# - ✂️ Include chunking, extracting metadata, and embedding each chunk in transformations.
#
# - 🌟 Nodes are a first-class citizen in LlamaIndex, allowing direct definition or parsing from Documents.
#
# - 🔄 Transformation inputs and outputs are `Node` objects (Note: `Document` is subclass of `Node`).
#
# - 🛠️ Nodes are "chunks" of Documents, including text, images, etc., plus metadata and relationships.
#
# - 📊 `NodeParser` classes convert Documents into Nodes with all necessary attributes. There are [a number of](https://docs.llamaindex.ai/en/stable/module_guides/loading/node_parsers/modules.html) `NodeParser`'s you can choose from!
#
# - 📑 High-level API: Use `.from_documents()` for automatic parsing and chunking of Document objects.
#
# - 🔍 Underlying process splits Document into Node objects, maintaining text and metadata with a link to their parent Document.

# %%
docs = ['skin_in_the_game.pdf', 'almanack_of_naval_ravikant.pdf', 'pg5.txt', 'striking-thoughts.pdf', 'taoofseneca_vol2.pdf', 'pg2.txt', 'pg10.txt', 'pg9.txt', 'pg1.txt', 'taoofseneca_vol1-1.pdf', 'pg8.txt', 'pg4.txt', 'pg3.txt', 'pg7.txt', 'anthology_of_balaji.pdf', 'taoofseneca_vol3.pdf', 'hackers_and_painters.pdf', 'pg6.txt']
documents = [  Document(text=doc) if type(doc) is str else Document(pdf=doc) for doc in docs ]
print(f"documents: {documents}")

parser = SentenceSplitter(
    chunk_size=128, # in tokens
    chunk_overlap=16, #in tokens
    paragraph_separator="\n\n"
)

nodes = parser.get_nodes_from_documents(documents, show_progress=True)
# Out:
# documents: [Document(id_='b61a634f-e7b9-4c71-921e-395317dd5b12', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='skin_in_the_game.pdf', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='1a9538d2-0573-40f5-89a6-7e9d5e8c8800', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='almanack_of_naval_ravikant.pdf', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='594872e0-df73-445c-b128-4685e7ee1251', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='pg5.txt', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='e6384773-5eda-49f3-a833-f6568f1bce96', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='striking-thoughts.pdf', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='3f9b379b-07fc-4438-9894-ad16da001754', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='taoofseneca_vol2.pdf', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='577cf5d8-8c8a-403e-9589-4e333458be79', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='pg2.txt', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='a0911739-26bf-4b09-925b-203a3b3bd719', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='pg10.txt', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='1cfb96d8-d1fd-4e9c-9d2f-5acbaf0248ea', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='pg9.txt', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='bc84ac1d-5d68-48fe-bab0-774114f03f16', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='pg1.txt', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='39d3bf4f-d294-473e-b5ec-e8ea9f79ff73', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='taoofseneca_vol1-1.pdf', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='e625e27e-8750-4480-b7ae-f66da2c3bef5', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='pg8.txt', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='2bccd0be-9a72-464b-868c-eb358a28eb7b', embedd ...
# Parsing nodes:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
print(nodes)
print(len(nodes))
type(nodes[17])
#type(nodes[42])
# Out:
# [TextNode(id_='b1ff5fbc-fb6d-4080-a6dc-32396d33a61f', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='b61a634f-e7b9-4c71-921e-395317dd5b12', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='c9d80702ccc1b5ad2fbdfef851975a9acd6c68a56e23a41de6ccc7f02e6276fc')}, text='skin_in_the_game.pdf', mimetype='text/plain', start_char_idx=0, end_char_idx=20, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='a0640cc3-f0c8-4aef-b1ce-a46044f254c0', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1a9538d2-0573-40f5-89a6-7e9d5e8c8800', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='152aab357583b4856bfb0de646b9da20471bb8d57c6738007fb077aa72bbb01b')}, text='almanack_of_naval_ravikant.pdf', mimetype='text/plain', start_char_idx=0, end_char_idx=30, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='bc53574e-3868-43d5-8aa6-3335b2cff9d7', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='594872e0-df73-445c-b128-4685e7ee1251', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='8466f6f1a5f6eacf863e4813c0b021cc1586c5b6ee3f6818c001e4202c8e5a4c')}, text='pg5.txt', mimetype='text/plain', start_char_idx=0, end_char_idx=7, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='168392af-22c8-46d7-a161-5dabd3c1001d', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e6384773-5eda-49f3-a833-f6568f1bce96', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='bb4486f084e25a4669560a7d62ef152e774a017e44dba1188b4338f417768abb')}, text='striking-thoughts.pdf', mimetype='text/plain', start_char_idx=0, end_char_idx=21, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='2f61d2fa-0df8-47ad-881d-a19d9d793b87', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='3f9b379b-07fc-4438-9894-ad16da001754', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='6e9df869d7089588ca45507006be3f31fabd734b9dba32aba02e2b2d4455fb60')}, text='taoofseneca_vol2.pdf', mimetype='text/plain', start_char_idx=0, end_char_idx=20, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='f9202e65-e706-4153-a2f2-0c3805c29013', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='577cf5d8-8c8a-403e-9589-4e333458be79', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='6f2d438e533300b8df92ad55066ba957af26034199145123517e32e63fd34060')}, text='pg2.txt', mimetype='text/plain', start_char_idx=0, end_char_idx=7, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='aac5314a-e25b-43f4-ba08-561f92b6cf92', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='a0911739-26bf-4b09-925b-203a3b3bd719', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='7070953a572b225c10d1416c8bacbaaeb54603008b377fae9a452788ee659fdc')}, text='pg10.txt', mimetype='text/plain', start_char_idx=0, end_char_idx=8, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperat ...
# 18
# llama_index.core.schema.TextNode

# %%
nodes[17].__dict__
# Out:
# {'id_': 'd2931859-086a-4c6e-a097-1dd72b0e3f17',
#  'embedding': None,
#  'metadata': {},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='48a01fa5-e942-4269-b249-b10371422e7e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='2129f24bbedfab205aa1e7617d12a345ccdee779f5ea66377404134051d510b8')},
#  'text': 'pg6.txt',
#  'mimetype': 'text/plain',
#  'start_char_idx': 0,
#  'end_char_idx': 7,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n'}

# %% [markdown]
# You can also choose to construct Node objects manually.

# %%
from llama_index.core.schema import TextNode, NodeRelationship, RelatedNodeInfo

node1 = TextNode(text="Dad is married to Mom", id_="001")

node2 = TextNode(text="Dad is Son's dad", id_="002")

# %% [markdown]
# ## NodeRelationships
#
# You can set relationships between nodes.
#
# - 🌐 NodeRelationships assign connections between chunks of text. It's useful for:
#   - Documents organized in a hierarchical manner (e.g., book, chapter, section, subsection)
#   - Maintaining sequential order
#   - Other complex relationships (ie, in legal documents for links a clause or other cases)
#
# - 🔍 NodeRelationships help retrieve not just the relevant section, but also related sections that might provide additional context or information.

# %%
node1.relationships[NodeRelationship.NEXT] = RelatedNodeInfo(
    node_id=node2.node_id
)

node2.relationships[NodeRelationship.PREVIOUS] = RelatedNodeInfo(
    node_id=node1.node_id
)
nodes = [node1, node2]

node2.relationships[NodeRelationship.PARENT] = RelatedNodeInfo(
    node_id=node1.node_id, metadata={"Romie": "Mom", "Harpreet": "Dad", "Jind":"Daughter", "Jugaad":"Son"}, 
)

# %% [markdown]
# A bit of clean up, let's just go ahead and delete the text files we downloaded since we won't need them going forward.

# %%
# !rm -rf ./data
